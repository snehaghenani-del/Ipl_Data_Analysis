# %% [markdown]
# # Exploratory Data Analysis of IPL-Matches(2008-2022)
# As you all know Cricket is a sport played and watched by millions of people around the world but Indians are mad about cricket. Cricket is played in our streets. We like it so much. People in india are crazy about the game. Cricket is a Gentlemen Game , As a cricket lover, I decided to analyze the data of IPL matches. Why IPL match? Because cricket is not a game of any specific country or a nation, I love Indian league IPL .So, that why I shall anlyze the data of IPL matches from 2008 to 2022.
#
# - I found IPL matches (2008-2022) dataset from kaggle.
# - Here is the link of IPL matches Dataset: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv

# %% [markdown]
# ## Data Selection and Installing
# First we will select appropriate dataset from kaggle which I have done. You can check it at this link: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv. To download our dataset we have to install opendataset library by pip install command.

# %% [markdown]
# # Essential Libraries for this project
#  * Lets import essential libraries fr this project

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# settings
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Analysing IPL match dataset

# %% [markdown]
# ## Data Preparation and Cleaning
# First, we load our dataset into DataFrame and see our DataFrame some first and last rows to overview of dataset

# %%
 df = pd.read_csv(r"C:\Users\klemp\Desktop\DataAanalyst (RCB)\IPL_Matches_EDA-main\IPL_Matches_EDA-main\IPL_Matches_2008_2022.csv")

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
df.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players    Umpire1  \
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...  BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...   SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...  Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...  MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  Asad Rauf
#
#             Umpire2
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['method']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 945    NaN
# 946    NaN
# 947    NaN
# 948    NaN
# 949    NaN
# Name: method, Length: 950, dtype: object

# %%
df['method'].isnull().sum()
# Out:
# np.int64(931)

# %% [markdown]
# By looking at the dataset we can see that our dataset contains many rows and columns. The dataset includes **MatchNumber**, **Team1**, **Team2**, **Venue**, **Team1Players**, **Team2Players**, **Umpire1** and **Umpire2** Data which gives us information about where match held, which teams played a match and about team players, about umpires also and information about **winning team** and win stats.

# %%
df.shape
# Out:
# (950, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %% [markdown]
# > 950 - rows & 20 cls in ipl match dataset

# %%
# cols which contains null values
# # City , SuperOver ,WinningTeam,Margin,Method,Player_of_Match

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df.describe() ['Margin']
# Out:
# count    932.000000
# mean      17.056867
# std       21.633109
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%       19.000000
# max      146.000000
# Name: Margin, dtype: float64

# %%
df.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
df['WonBy'].value_counts()
# Out:
# WonBy
# Wickets      509
# Runs         423
# SuperOver     14
# NoResults      4
# Name: count, dtype: int64

# %%
# GroupBy
df.groupby('WonBy')['Margin'].max()
# Out:
# WonBy
# NoResults      NaN
# Runs         146.0
# SuperOver      NaN
# Wickets       10.0
# Name: Margin, dtype: float64

# %% [markdown]
# #### The above table provides us with very useful information. By above table we can see that as of 2022, there have been 15 seasons of IPL tournament hosted by 33 cities. Although, 18 teams have played and 262 Players become player of match in past seasons of IPL.

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1012)

# %%
print("Total Null Cells  :",df.isnull().sum().sum())
df.isnull().sum()
# Out:
# Total Null Cells  : 1012
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %% [markdown]
# In our DataFrame the date should be a string that represent date for future work with date. Let's convert all cells in **Date** column to dates. Pandas have **datetime()** method for this.

# %%
df['Date']=pd.to_datetime(df['Date']) # obj => Date Time

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date'][0]
# Out:
# Timestamp('2022-05-29 00:00:00')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    datetime64[ns]
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(17)
# memory usage: 148.6+ KB

# %%
df['Date']
# Out:
# 0     2022-05-29
# 1     2022-05-27
# 2     2022-05-25
# 3     2022-05-24
# 4     2022-05-22
#          ...
# 945   2008-04-20
# 946   2008-04-20
# 947   2008-04-19
# 948   2008-04-19
# 949   2008-04-18
# Name: Date, Length: 950, dtype: datetime64[ns]

# %% [markdown]
# Now, we will clean empty cells, wrong data and unusual data. We will also check any duplicate data in our dataset.

# %%
#checking duplicate vallues
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  There are no duplicates within the dataset

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# ID       City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# 336022   Delhi          2008-05-17  2007/08  40           Delhi Daredevils             Kings XI Punjab              Feroz Shah Kotla                                     Delhi Daredevils             bat           N          Kings XI Punjab              Runs     6.0     D/L     DPMD Jayawardene  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'TM Dilshan', 'MF Maharoof', 'Shoaib Malik', 'PJ Sangwan', 'KD Karthik', 'A Mishra', 'R Bhatia', 'GD McGrath']       ['SE Marsh', 'JR Hopes', 'Yuvraj Singh', 'LA Pomersbach', 'DPMD Jayawardene', 'IK Pathan', 'RR Powar', 'PP Chawla', 'U Kaul', 'S Sreesanth', 'VRV Singh']    AV Jayaprakash         RE Koertzen        1
# 336025   Kolkata        2008-05-18  2007/08  41           Kolkata Knight Riders        Chennai Super Kings          Eden Gardens                                         Kolkata Knight Riders        bat           N          Chennai Super Kings          Runs     3.0     D/L     M Ntini           ['Salman Butt', 'Mohammad Hafeez', 'SC Ganguly', 'DB Das', 'DJ Hussey', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'I Sharma', 'AB Dinda', 'Shoaib Akhtar']     ['PA Patel', 'SP Fleming', 'S Vidyut', 'SK Raina', 'S Badrinath', 'MS Dhoni', 'JA Morkel', 'MS Gony', 'L Balaji', 'M Muralitharan', 'M Ntini']               Asad Rauf              K Hariharan        1
# 392183   Cape Town      2009-04-19  2009     3            Delhi Daredevils             Kings XI Punjab              Newlands                                             Delhi Daredevils             field         N          Delhi Daredevils             Wickets  10.0    D/L     DL Vettori        ['G Gambhir', 'V Sehwag', 'TM Dilshan', 'AB de Villiers', 'MK Tiwary', 'KD Karthik', 'DP Nannes', 'DL Vettori', 'VY Mahesh', 'AM Salvi', 'PJ Sangwan']     ['RS Bopara', 'K Goel', 'Yuvraj Singh', 'KC Sangakkara', 'DPMD Jayawardene', 'IK Pathan', 'PP Chawla', 'T Kohli', 'VS Malik', 'VRV Singh', 'YA Abdulla']     MR Benson              SD Ranade          1
# 392186   Durban         2009-04-21  2009     6            Kings XI Punjab              Kolkata Knight Riders        Kingsmead                                            Kolkata Knight Riders        field         N          Kolkata Knight Riders        Runs     11.0    D/L     CH Gayle          ['RS Bopara', 'K Goel', 'IK Pathan', 'KC Sangakkara', 'Yuvraj Singh', 'DPMD Jayawardene', 'T Kohli', 'PP Chawla', 'VS Malik', 'VRV Singh', 'YA Abdulla']   ['BB McCullum', 'CH Gayle', 'BJ Hodge', 'SC Ganguly', 'Yashpal Singh', 'A Chopra', 'MC Henriques', 'LR Shukla', 'I Sharma', 'M Kartik', 'AB Dinda']          DJ Harper              SD Ranade          1
# 392214   Centurion      2009-05-07  2009     34           Chennai Super Kings          Kings XI Punjab              SuperSport Park                                      Chennai Super Kings          bat           N          Chennai Super Kings          Runs     12.0    D/L     ML Hayden         ['S Badrinath', 'ML Hayden', 'SK Raina', 'MS Dhoni', 'JA Morkel', 'GJ Bailey', 'S Tyagi', 'SB Jakati', 'L Balaji', 'M Muralitharan', 'MS Gony']            ['S Sohal', 'SM Katich', 'K Goel', 'Yuvraj Singh', 'DPMD Jayawardene', 'KC Sangakkara', 'IK Pathan', 'S Sreesanth', 'PP Chawla', 'YA Abdulla', 'VRV Singh']  DJ Harper              TH Wijewardene     1
# 501215   Kochi          2011-04-18  2011     18           Kochi Tuskers Kerala         Chennai Super Kings          Nehru Stadium                                        Kochi Tuskers Kerala         field         N          Kochi Tuskers Kerala         Wickets  7.0     D/L     BB McCullum       ['BB McCullum', 'DPMD Jayawardene', 'PA Patel', 'BJ Hodge', 'RA Jadeja', 'KM Jadhav', 'NLTC Perera', 'RV Gomez', 'R Vinay Kumar', 'RP Singh', 'RR Powar']  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badrinath', 'MS Dhoni', 'JA Morkel', 'S Anirudha', 'R Ashwin', 'SB Jakati', 'TG Southee', 'DE Bollinger']           K Hariharan            AL Hill            1
# 501245   Kolkata        2011-05-07  2011     48           Kolkata Knight Riders        Chennai Super Kings          Eden Gardens                                         Chennai Super Kings          bat           N          Kolkata Knight Riders        Runs     10.0    D/L     Iqbal Abdulla     ['EJG Morgan', 'JH Kallis', 'G Gambhir', 'MK Tiwary', 'YK Pathan', 'MV Boucher', 'R Bhatia', 'Iqbal Abdulla', 'B Lee', 'L Balaji', 'JD Unadkat']           ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badrinath', 'JA Morkel', 'MS Dhoni', 'WP Saha', 'R Ashwin', 'DE Bollinger', 'SB Jakati', 'S Randiv']                Asad Rauf              PR Reiffel         1
# 501255   Bangalore      2011-05-14  2011     58           Royal Challengers Bangalore  Kolkata Knight Riders        M Chinnaswamy Stadium                                Royal Challengers Bangalore  field         N          Royal Challengers Bangalore  Wickets  4.0     D/L     CH Gayle          ['CH Gayle', 'LA Pomersbach', 'V Kohli', 'AB de Villiers', 'M Kaif', 'KB Arun Karthik', 'SS Tiwary', 'A Mithun', 'Z Khan', 'S Aravind', 'CK Langeveldt']   ['JH Kallis', 'EJG Morgan', 'G Gambhir', 'MK Tiwary', 'YK Pathan', 'MV Boucher', 'R Bhatia', 'Iqbal Abdulla', 'B Lee', 'L Balaji', 'JD Unadkat']             RE Koertzen            RB Tiffin          1
# 733993   Delhi          2014-05-10  2014     32           Delhi Daredevils             Sunrisers Hyderabad          Feroz Shah Kotla                                     Sunrisers Hyderabad          field         N          Sunrisers Hyderabad          Wickets  8.0     D/L     DW Steyn          ['Q de Kock', 'KP Pietersen', 'MA Agarwal', 'KD Karthik', 'LR Shukla', 'JP Duminy', 'KM Jadhav', 'R Shukla', 'Mohammed Shami', 'Imran Tahir', 'S Kaul']    ['AJ Finch', 'S Dhawan', 'DA Warner', 'NV Ojha', 'KL Rahul', 'MC Henriques', 'IK Pathan', 'KV Sharma', 'DW Steyn', 'A Mishra', 'B Kumar']                    RM Deshpande           BNJ Oxenford       1
# 829743   Visakhapatnam  2015-04-22  2015     19           Sunrisers Hyderabad          Kolkata Knight Riders        Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  Kolkata Knight Riders        field         N          Sunrisers Hyderabad          Runs     16.0    D/L     DA Warner         ['S Dhawan', 'DA Warner', 'RS Bopara', 'NV Ojha', 'MC Henriques', 'KL Rahul', 'KV Sharma', 'Bipul Sharma', 'P Kumar', 'B Kumar', 'DW Steyn']               ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'AD Russell', 'YK Pathan', 'SA Yadav', 'J Botha', 'PP Chawla', 'SP Narine', 'M Morkel', 'UT Yadav']                 RK Illingworth         VA Kulkarni        1
# 829807   Hyderabad      2015-05-15  2015     52           Sunrisers Hyderabad          Royal Challengers Bangalore  Rajiv Gandhi International Stadium, Uppal            Sunrisers Hyderabad          bat           N          Royal Challengers Bangalore  Wickets  6.0     D/L     V Kohli           ['DA Warner', 'S Dhawan', 'MC Henriques', 'EJG Morgan', 'NV Ojha', 'KL Rahul', 'Bipul Sharma', 'KV Sharma', 'B Kumar', 'P Kumar', 'DW Steyn']              ['CH Gayle', 'V Kohli', 'AB de Villiers', 'Mandeep Singh', 'KD Karthik', 'SN Khan', 'D Wiese', 'MA Starc', 'HV Patel', 'YS Chahal', 'AB Dinda']              AK Chaudhary           HDPK Dharmasena    1
# 980943   Hyderabad      2016-04-26  2016     22           Sunrisers Hyderabad          Rising Pune Supergiants      Rajiv Gandhi International Stadium, Uppal            Rising Pune Supergiants      field         N          Rising Pune Supergiants      Runs     34.0    D/L     AB Dinda          ['DA Warner', 'S Dhawan', 'AP Tare', 'EJG Morgan', 'DJ Hooda', 'MC Henriques', 'NV Ojha', 'Bipul Sharma', 'B Kumar', 'A Nehra', 'Mustafizur Rahman']       ['AM Rahane', 'F du Plessis', 'SPD Smith', 'MS Dhoni', 'SS Tiwary', 'NLTC Perera', 'MR Marsh', 'R Bhatia', 'R Ashwin', 'M Ashwin', 'AB Dinda']               AY Dandekar            CK Nandan          1
# 980989   Kolkata        2016-05-14  2016     45           Kolkata Knight Riders        Rising Pune Supergiants      Eden Gardens                                         Rising Pune Supergiants      bat           N          Kolkata Knight Riders        Wickets  8.0     D/L     YK Pathan         ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK Pathan', 'Shakib Al Hasan', 'SA Yadav', 'AD Russell', 'PP Chawla', 'SP Narine', 'AS Rajpoot', 'M Morkel']     ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS Tiwary', 'IK Pathan', 'MS Dhoni', 'NLTC Perera', 'R Ashwin', 'A Zampa', 'M Ashwin', 'AB Dinda']                 A Nand Kishore         BNJ Oxenford       1
# 980997   Visakhapatnam  2016-05-17  2016     49           Rising Pune Supergiants      Delhi Daredevils             Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  Rising Pune Supergiants      field         N          Rising Pune Supergiants      Runs     19.0    D/L     AB Dinda          ['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS Tiwary', 'IK Pathan', 'MS Dhoni', 'NLTC Perera', 'R Ashwin', 'A Zampa', 'AB Dinda', 'DL Chahar']              ['Q de Kock', 'SS Iyer', 'KK Nair', 'SV Samson', 'RR Pant', 'JP Duminy', 'CH Morris', 'NM Coulter-Nile', 'A Mishra', 'Z Khan', 'Mohammed Shami']             Nitin Menon            C Shamshuddin      1
# 980999   Bangalore      2016-05-18  2016     50           Royal Challengers Bangalore  Kings XI Punjab              M Chinnaswamy Stadium                                Kings XI Punjab              field         N          Royal Challengers Bangalore  Runs     82.0    D/L     V Kohli           ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL Rahul', 'SR Watson', 'Sachin Baby', 'STR Binny', 'CJ Jordan', 'S Aravind', 'VR Aaron', 'YS Chahal']          ['M Vijay', 'HM Amla', 'WP Saha', 'DA Miller', 'Gurkeerat Singh', 'AR Patel', 'F Behardien', 'KJ Abbott', 'MM Sharma', 'KC Cariappa', 'Sandeep Sharma']      KN Ananthapadmanabhan  M Erasmus          1
# 1082648  Bangalore      2017-05-17  2017     Eliminator   Sunrisers Hyderabad          Kolkata Knight Riders        M Chinnaswamy Stadium                                Kolkata Knight Riders        field         N          Kolkata Knight Riders        Wickets  7.0     D/L     NM Coulter-Nile   ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yuvraj Singh', 'V Shankar', 'NV Ojha', 'CJ Jordan', 'Bipul Sharma', 'B Kumar', 'Rashid Khan', 'S Kaul']        ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gambhir', 'IR Jaggi', 'SA Yadav', 'SP Narine', 'PP Chawla', 'UT Yadav', 'NM Coulter-Nile', 'TA Boult']             AK Chaudhary           Nitin Menon        1
# 1136566  Jaipur         2018-04-11  2018     6            Rajasthan Royals             Delhi Daredevils             Sawai Mansingh Stadium                               Delhi Daredevils             field         N          Rajasthan Royals             Runs     10.0    D/L     SV Samson         ['AM Rahane', 'DJM Short', 'BA Stokes', 'SV Samson', 'JC Buttler', 'RA Tripathi', 'K Gowtham', 'S Gopal', 'DS Kulkarni', 'JD Unadkat', 'B Laughlin']       ['GJ Maxwell', 'C Munro', 'RR Pant', 'CH Morris', 'V Shankar', 'SS Iyer', 'G Gambhir', 'R Tewatia', 'S Nadeem', 'TA Boult', 'Mohammed Shami']                KN Ananthapadmanabhan  Nitin Menon        1
# 1136578  Kolkata        2018-04-21  2018     18           Kolkata Knight Riders        Kings XI Punjab              Eden Gardens                                         Kings XI Punjab              field         N          Kings XI Punjab              Wickets  9.0     D/L     KL Rahul          ['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana', 'KD Karthik', 'AD Russell', 'Shubman Gill', 'TK Curran', 'PP Chawla', 'Shivam Mavi', 'Kuldeep Yadav']     ['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nair', 'AJ Finch', 'Yuvraj Singh', 'R Ashwin', 'AJ Tye', 'BB Sran', 'Mujeeb Ur Rahman', 'AS Rajpoot']             A Deshmukh             C Shamshuddin      1
# 1136592  Delhi          2018-05-02  2018     32           Delhi Daredevils             Rajasthan Royals             Arun Jaitley Stadium                                 Rajasthan Royals             field         N          Delhi Daredevils             Runs     4.0     D/L     RR Pant           ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', 'GJ Maxwell', 'V Shankar', 'LE Plunkett', 'A Mishra', 'S Nadeem', 'Avesh Khan', 'TA Boult']                   ['DJM Short', 'JC Buttler', 'SV Samson', 'BA Stokes', 'RA Tripathi', 'K Gowtham', 'JC Archer', 'AM Rahane', 'JD Unadkat', 'DS Kulkarni', 'S Gopal']          CK Nandan              VK Sharma          1
# Name: count, dtype: int64

# %%
df['City']=df['City'].replace('Bengaluru','Bangalore')

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          80
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          80
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# In IPL there are some teams whose named changed after some season. So, we will also rename the teams to get more efficient analysis.

# %%
df['Team1']=df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
df['Team2']=df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
df['WinningTeam']=df['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
[df['Team1'].value_counts()]
# Out:
# [Team1
#  Royal Challengers Bangalore    126
#  Mumbai Indians                 112
#  Chennai Super Kings            111
#  Punjab Kings                   110
#  Kolkata Knight Riders          105
#  Rajasthan Royals                89
#  Delhi Daredevils                85
#  Sunrisers Hyderabad             69
#  Deccan Chargers                 39
#  Delhi Capitals                  29
#  Pune Warriors                   23
#  Gujarat Lions                   16
#  Lucknow Super Giants             8
#  Gujarat Titans                   7
#  Rising Pune Supergiant           7
#  Rising Pune Supergiants          7
#  Kochi Tuskers Kerala             7
#  Name: count, dtype: int64]

# %%
[df['Team2'].value_counts()]
# Out:
# [Team2
#  Mumbai Indians                 119
#  Kolkata Knight Riders          118
#  Punjab Kings                   108
#  Rajasthan Royals               103
#  Royal Challengers Bangalore    100
#  Chennai Super Kings             97
#  Sunrisers Hyderabad             83
#  Delhi Daredevils                76
#  Deccan Chargers                 36
#  Delhi Capitals                  34
#  Pune Warriors                   23
#  Gujarat Lions                   14
#  Gujarat Titans                   9
#  Rising Pune Supergiant           9
#  Lucknow Super Giants             7
#  Rising Pune Supergiants          7
#  Kochi Tuskers Kerala             7
#  Name: count, dtype: int64]

# %%
[df['WinningTeam'].value_counts()]
# Out:
# [WinningTeam
#  Mumbai Indians                 131
#  Chennai Super Kings            121
#  Kolkata Knight Riders          114
#  Royal Challengers Bangalore    109
#  Punjab Kings                   101
#  Rajasthan Royals                96
#  Sunrisers Hyderabad             75
#  Delhi Daredevils                67
#  Delhi Capitals                  36
#  Deccan Chargers                 29
#  Gujarat Lions                   13
#  Gujarat Titans                  12
#  Pune Warriors                   12
#  Rising Pune Supergiant          10
#  Lucknow Super Giants             9
#  Kochi Tuskers Kerala             6
#  Rising Pune Supergiants          5
#  Name: count, dtype: int64]

# %%
df.TossWinner
# Out:
# 0                 Rajasthan Royals
# 1                 Rajasthan Royals
# 2             Lucknow Super Giants
# 3                   Gujarat Titans
# 4              Sunrisers Hyderabad
#                   ...
# 945                Deccan Chargers
# 946                 Mumbai Indians
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949    Royal Challengers Bangalore
# Name: TossWinner, Length: 950, dtype: object

# %%
df['TossWinner']=df['TossWinner'].replace('Kings XI Punjab','Punjab Kings')

# %%
df.TossWinner.value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].replace('Delhi Daredevils','Delhi Capitals')

# %%
df['Team2']=df['Team2'].replace('Delhi Daredevils','Delhi Capitals')

# %%
df['WinningTeam']=df['WinningTeam'].replace('Delhi Daredevils','Delhi Capitals')

# %%
df.Team1.value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Delhi Capitals                 103
# Punjab Kings                   101
# Rajasthan Royals                96
# Sunrisers Hyderabad             75
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df.TossWinner.value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['Team2']=df['Team2'].replace('Rising Pune Supergiants','Rising Pune Supergiant')

df['WinningTeam']=df['WinningTeam'].replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %% [markdown]
# ## Dealing with null values

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df[c1]
# Out:
#           ID City       Date   Season MatchNumber  \
# 138  1216495  NaN 2020-11-03  2020/21          56
# 143  1216502  NaN 2020-10-31  2020/21          52
# 148  1216520  NaN 2020-10-26  2020/21          46
# 153  1216521  NaN 2020-10-23  2020/21          41
# 161  1216509  NaN 2020-10-17  2020/21          34
# 163  1216531  NaN 2020-10-15  2020/21          31
# 166  1216540  NaN 2020-10-12  2020/21          28
# 171  1216500  NaN 2020-10-09  2020/21          23
# 177  1216538  NaN 2020-10-04  2020/21          17
# 179  1216515  NaN 2020-10-03  2020/21          16
# 185  1216527  NaN 2020-09-27  2020/21           9
# 190  1216496  NaN 2020-09-22  2020/21           4
# 535   729311  NaN 2014-04-27     2014          17
# 536   729309  NaN 2014-04-27     2014          16
# 541   729299  NaN 2014-04-24     2014          11
# 543   729295  NaN 2014-04-22     2014           9
# 545   729291  NaN 2014-04-20     2014           7
# 550   729281  NaN 2014-04-17     2014           2
#
#                            Team1                        Team2  \
# 138               Mumbai Indians          Sunrisers Hyderabad
# 143  Royal Challengers Bangalore          Sunrisers Hyderabad
# 148        Kolkata Knight Riders                 Punjab Kings
# 153          Chennai Super Kings               Mumbai Indians
# 161          Chennai Super Kings               Delhi Capitals
# 163  Royal Challengers Bangalore                 Punjab Kings
# 166  Royal Challengers Bangalore        Kolkata Knight Riders
# 171               Delhi Capitals             Rajasthan Royals
# 177               Mumbai Indians          Sunrisers Hyderabad
# 179               Delhi Capitals        Kolkata Knight Riders
# 185                 Punjab Kings             Rajasthan Royals
# 190             Rajasthan Royals          Chennai Super Kings
# 535          Sunrisers Hyderabad          Chennai Super Kings
# 536               Delhi Capitals               Mumbai Indians
# 541  Royal Challengers Bangalore        Kolkata Knight Riders
# 543                 Punjab Kings          Sunrisers Hyderabad
# 545             Rajasthan Royals                 Punjab Kings
# 550               Delhi Capitals  Royal Challengers Bangalore
#
#                        Venue                   TossWinner TossDecision  \
# 138  Sharjah Cricket Stadium          Sunrisers Hyderabad        field
# 143  Sharjah Cricket Stadium          Sunrisers Hyderabad        field
# 148  Sharjah Cricket Stadium                 Punjab Kings        field
# 153  Sharjah Cricket Stadium               Mumbai Indians        field
# 161  Sharjah Cricket Stadium          Chennai Super Kings          bat
# 163  Sharjah Cricket Stadium  Royal Challengers Bangalore          bat
# 166  Sharjah Cricket Stadium  Royal Challengers Bangalore          bat
# 171  Sharjah Cricket Stadium             Rajasthan Royals        field
# 177  Sharjah Cricket Stadium               Mumbai Indians          bat
# 179  Sharjah Cricket Stadium        Kolkata Knight Riders        field
# 185  Sharjah Cricket Stadium             Rajasthan Royals        field
# 190  Sharjah Cricket Stadium          Chennai Super Kings        field
# 535  Sharjah Cricket Stadium          Sunrisers Hyderabad          bat
# 536  Sharjah Cricket Stadium               Mumbai Indians          bat
# 541  Sharjah Cricket Stadium  Royal Challengers Bangalore        field
# 543  Sharjah Cricket Stadium          Sunrisers Hyderabad        field
# 545  Sharjah Cricket Stadium                 Punjab Kings        field
# 550  Sharjah Cricket Stadium  Royal Challengers Bangalore        field
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 138         N          Sunrisers Hyderabad  Wickets    10.0    NaN
# 143         N          Sunrisers Hyderabad  Wickets     5.0    NaN
# 148         N                 Punjab Kings  Wickets     8.0    NaN
# 153         N               Mumbai Indians  Wickets    10.0    NaN
# 161         N               Delhi Capitals  Wickets     5.0    NaN
# 163         N                 Punjab Kings  Wickets     8.0    NaN
# 166         N  Royal Challengers Bangalore     Runs    82.0    NaN
# 171         N               Delhi Capitals     Runs    46.0    NaN
# 177         N               Mumbai Indians     Runs    34.0    NaN
# 179         N               Delhi Capitals     Runs    18.0    NaN
# 185         N             Rajasthan Royals  Wickets     4.0    NaN
# 190         N             Rajasthan Royals     Runs    16.0    NaN
# 535         N          Chennai Super Kings  Wickets     5.0    NaN
# 536         N               Delhi Capitals  Wickets     6.0    NaN
# 541         N        Kolkata Knight Riders     Runs     2.0    NaN
# 543         N                 Punjab Kings     Runs    72.0    NaN
# 545         N                 Punjab Kings  Wickets     7.0    NaN
# 550         N  Royal Challengers Bangalore  Wickets     8.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 138        S Nadeem  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 143  Sandeep Sharma  ['JR Philippe', 'D Padikkal', 'V Kohli', 'AB d...
# 148        CH Gayle  ['Shubman Gill', 'N Rana', 'RA Tripathi', 'KD ...
# 153        TA Boult  ['RD Gaikwad', 'F du Plessis', 'AT Rayudu', 'N...
# 161        S Dhawan  ['SM Curran', 'F du Plessis', 'SR Watson', 'AT...
# 163        KL Rahul  ['AJ Finch', 'D Padikkal', 'V Kohli', 'Washing...
# 166  AB de Villiers  ['AJ Finch', 'D Padikkal', 'V Kohli', 'AB de V...
# 171        R Ashwin  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 177        TA Boult  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 179         SS Iyer  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
# 185       SV Samson  ['KL Rahul', 'MA Agarwal', 'GJ Maxwell', 'N Po...
# 190       SV Samson  ['YBK Jaiswal', 'SPD Smith', 'SV Samson', 'DA ...
# 535        DR Smith  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...
# 536         M Vijay  ['Q de Kock', 'M Vijay', 'JP Duminy', 'KP Piet...
# 541         CA Lynn  ['PA Patel', 'YV Takawale', 'V Kohli', 'Yuvraj...
# 543      GJ Maxwell  ['CA Pujara', 'V Sehwag', 'GJ Maxwell', 'DA Mi...
# 545      GJ Maxwell  ['AM Nayar', 'AM Rahane', 'SV Samson', 'SR Wat...
# 550       YS Chahal  ['MA Agarwal', 'M Vijay', 'KD Karthik', 'MK Ti...
#
#                                           Team2Players                Umpire1  \
# 138  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...          C Shamshuddin
# 143  ['DA Warner', 'WP Saha', 'MK Pandey', 'KS Will...  KN Ananthapadmanabhan
# 148  ['KL Rahul', 'Mandeep Singh', 'CH Gayle', 'N P...  KN Ananthapadmanabhan
# 153  ['Q de Kock', 'Ishan Kishan', 'SA Yadav', 'SS ...          C Shamshuddin
# 161  ['PP Shaw', 'S Dhawan', 'AM Rahane', 'SS Iyer'...  KN Ananthapadmanabhan
# 163  ['KL Rahul', 'MA Agarwal', 'CH Gayle', 'N Poor...  KN Ananthapadmanabhan
# 166  ['T Banton', 'Shubman Gill', 'N Rana', 'EJG Mo...         RK Illingworth
# 171  ['YBK Jaiswal', 'JC Buttler', 'SPD Smith', 'SV...  KN Ananthapadmanabhan
# 177  ['DA Warner', 'JM Bairstow', 'MK Pandey', 'KS ...  KN Ananthapadmanabhan
# 179  ['Shubman Gill', 'SP Narine', 'N Rana', 'AD Ru...            VA Kulkarni
# 185  ['JC Buttler', 'SPD Smith', 'SV Samson', 'R Te...         RK Illingworth
# 190  ['M Vijay', 'SR Watson', 'F du Plessis', 'SM C...          C Shamshuddin
# 535  ['DR Smith', 'BB McCullum', 'SK Raina', 'MS Dh...           AK Chaudhary
# 536  ['RG Sharma', 'AP Tare', 'CJ Anderson', 'AT Ra...              Aleem Dar
# 541  ['JH Kallis', 'G Gambhir', 'MK Pandey', 'CA Ly...              Aleem Dar
# 543  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...              M Erasmus
# 545  ['CA Pujara', 'V Sehwag', 'WP Saha', 'GJ Maxwe...              BF Bowden
# 550  ['PA Patel', 'NJ Maddinson', 'V Kohli', 'Yuvra...              Aleem Dar
#
#             Umpire2
# 138  RK Illingworth
# 143    K Srinivasan
# 148  RK Illingworth
# 153     VA Kulkarni
# 161  RK Illingworth
# 163   C Shamshuddin
# 166    K Srinivasan
# 171   C Shamshuddin
# 177  RK Illingworth
# 179  RK Illingworth
# 185    K Srinivasan
# 190     VA Kulkarni
# 535     VA Kulkarni
# 536     VA Kulkarni
# 541     VA Kulkarni
# 543          S Ravi
# 545       M Erasmus
# 550          S Ravi

# %%
# city 
c1=df['City'].isnull()
df[c1].nunique()
# Out:
# ID                 51
# City                0
# Date               45
# Season              2
# MatchNumber        42
# Team1               8
# Team2               8
# Venue               2
# TossWinner          8
# TossDecision        2
# SuperOver           2
# WinningTeam         8
# WonBy               3
# Margin             26
# method              0
# Player_of_Match    38
# Team1Players       51
# Team2Players       49
# Umpire1            13
# Umpire2            10
# dtype: int64

# %%
 
c1=df['City'].isnull()
df[c1]['Venue'].value_counts()
# Out:
# Venue
# Dubai International Cricket Stadium    33
# Sharjah Cricket Stadium                18
# Name: count, dtype: int64

# %%
vf=(df['Venue']=='Dubai International Cricket Stadium') #dubai= city
df[vf]['City'].replace
# Out:
# <bound method NDFrame.replace of 74     Dubai
# 77     Dubai
# 78     Dubai
# 81     Dubai
# 84     Dubai
# 86     Dubai
# 89     Dubai
# 91     Dubai
# 94     Dubai
# 96     Dubai
# 101    Dubai
# 102    Dubai
# 104    Dubai
# 134      NaN
# 137      NaN
# 140      NaN
# 142      NaN
# 145      NaN
# 147      NaN
# 150      NaN
# 151      NaN
# 154      NaN
# 156      NaN
# 159      NaN
# 160      NaN
# 164      NaN
# 165      NaN
# 167      NaN
# 170      NaN
# 172      NaN
# 175      NaN
# 176      NaN
# 180      NaN
# 182      NaN
# 184      NaN
# 187      NaN
# 188      NaN
# 191      NaN
# 192      NaN
# 532      NaN
# 534      NaN
# 539      NaN
# 540      NaN
# 542      NaN
# 546      NaN
# 547      NaN
# Name: City, dtype: object>

# %%
vf=(df['Venue']=='Dubai International Cricket Stadium') #dubai= city
df[vf]['City'].index
# Out:
# Index([ 74,  77,  78,  81,  84,  86,  89,  91,  94,  96, 101, 102, 104, 134,
#        137, 140, 142, 145, 147, 150, 151, 154, 156, 159, 160, 164, 165, 167,
#        170, 172, 175, 176, 180, 182, 184, 187, 188, 191, 192, 532, 534, 539,
#        540, 542, 546, 547],
#       dtype='int64')

# %%
vf=(df['Venue']=='Dubai International Cricket Stadium') #dubai= city
df.loc[vf,'City']='Dubai'

# %%
vf
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: Venue, Length: 950, dtype: bool

# %%
df.loc[vf,'City'] =' Dubai'

# %%
vf1=(df['Venue']=='Sharjah Cricket Stadium') 
df.loc[vf,'City']='Sharjah'

# %%
vf1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: Venue, Length: 950, dtype: bool

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                18
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['SuperOver'].fillna('NoResult',inplace=True)
df['WinningTeam'].fillna('NoResult',inplace=True)
df['Player_of_Match'].fillna('NoResult',inplace= True)
df['Margin'].fillna('NoMargin',inplace = True)
# Out:
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\4171381129.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SuperOver'].fillna('NoResult',inplace=True)
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\4171381129.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WinningTeam'].fillna('NoResult',inplace=True)
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\4171381129.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Player_of_Match'].fillna('NoResult',inplace= True)
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\4171381129.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Margin'].fillna('NoMargin',inplace = True)
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\4171381129.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NoMargin' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Margin'].fillna('NoMargin',inplace = True)

# %%
df.drop(columns=['method'],inplace=True)

# %%
df.head()
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad 2022-05-29   2022        Final
# 1  1312199  Ahmedabad 2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata 2022-05-25   2022   Eliminator
# 3  1312197    Kolkata 2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai 2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy Margin Player_of_Match  \
# 0         N               Gujarat Titans  Wickets    7.0       HH Pandya
# 1         N             Rajasthan Royals  Wickets    7.0      JC Buttler
# 2         N  Royal Challengers Bangalore     Runs   14.0      RM Patidar
# 3         N               Gujarat Titans  Wickets    7.0       DA Miller
# 4         N                 Punjab Kings  Wickets    5.0   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %% [markdown]
# data has been cleaned for further processing

# %%
 dfb = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
dfb.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
dfb.shape
# Out:
# (225954, 17)

# %% [markdown]
# > in our dataset we have (225954- rows and  17 -col

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
#  15  fielders_involved  7988 non-null    object
#  16  BattingTeam        225954 non-null  object
# dtypes: int64(9), object(8)
# memory usage: 29.3+ MB

# %%
# checking duplicated
dfb.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# there are no dulicated values

# %%
## null value
dfb.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.drop(columns=['extra_type','player_out','kind','fielders_involved'] ,inplace=True)

# %%
dfb.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'batsman_run', 'extras_run', 'total_run', 'non_boundary',
#        'isWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb.rename(columns={'innings':'Innings','overs':'Overs','ballnumber':'Ballnumber','batter':'Batter', 'bowler':'Bowler',
       'non-striker':'Non-striker', 'batsman_run':'Batsman_run', 'extras_run':'Extra_run', 'total_run':'Total_run', 'non_boundary':'Non_boundary',
       'isWicketDelivery':'IsWicketDelivery'},inplace=True)

# %%
dfb.isnull().sum()
# Out:
# ID                  0
# Innings             0
# Overs               0
# Ballnumber          0
# Batter              0
# Bowler              0
# Non-striker         0
# Batsman_run         0
# Extra_run           0
# Total_run           0
# Non_boundary        0
# IsWicketDelivery    0
# BattingTeam         0
# dtype: int64

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# BattingTeam
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                  7587
# Delhi Daredevils               18786
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kings XI Punjab                22646
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                    3388
# Rajasthan Royals               22777
# Rising Pune Supergiant          1900
# Rising Pune Supergiants         1580
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: count, dtype: int64

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Delhi Daredevils ','Delhi Capitals  ')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Rising Pune Supergiants ','Rising Pune Supergiant ')

# %%
dfb.head(10)
# Out:
#         ID  Innings  Overs  Ballnumber       Batter          Bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6  1312200        1      1           1   JC Buttler      Yash Dayal
# 7  1312200        1      1           2   JC Buttler      Yash Dayal
# 8  1312200        1      1           3   JC Buttler      Yash Dayal
# 9  1312200        1      1           4   JC Buttler      Yash Dayal
#
#    Non-striker  Batsman_run  Extra_run  Total_run  Non_boundary  \
# 0   JC Buttler            0          0          0             0
# 1   JC Buttler            0          1          1             0
# 2  YBK Jaiswal            1          0          1             0
# 3   JC Buttler            0          0          0             0
# 4   JC Buttler            0          0          0             0
# 5   JC Buttler            0          0          0             0
# 6  YBK Jaiswal            0          0          0             0
# 7  YBK Jaiswal            0          0          0             0
# 8  YBK Jaiswal            4          0          4             0
# 9  YBK Jaiswal            0          0          0             0
#
#    IsWicketDelivery       BattingTeam
# 0                 0  Rajasthan Royals
# 1                 0  Rajasthan Royals
# 2                 0  Rajasthan Royals
# 3                 0  Rajasthan Royals
# 4                 0  Rajasthan Royals
# 5                 0  Rajasthan Royals
# 6                 0  Rajasthan Royals
# 7                 0  Rajasthan Royals
# 8                 0  Rajasthan Royals
# 9                 0  Rajasthan Royals

# %%
dfb['Ballnumber'].value_counts().sort_index()
# Out:
# Ballnumber
# 1     36599
# 2     36507
# 3     36413
# 4     36322
# 5     36201
# 6     36083
# 7      6585
# 8      1055
# 9       171
# 10       18
# Name: count, dtype: int64

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                225954 non-null  int64
#  1   Innings           225954 non-null  int64
#  2   Overs             225954 non-null  int64
#  3   Ballnumber        225954 non-null  int64
#  4   Batter            225954 non-null  object
#  5   Bowler            225954 non-null  object
#  6   Non-striker       225954 non-null  object
#  7   Batsman_run       225954 non-null  int64
#  8   Extra_run         225954 non-null  int64
#  9   Total_run         225954 non-null  int64
#  10  Non_boundary      225954 non-null  int64
#  11  IsWicketDelivery  225954 non-null  int64
#  12  BattingTeam       225954 non-null  object
# dtypes: int64(9), object(4)
# memory usage: 22.4+ MB

# %%
dfb.nunique()
# Out:
# ID                  950
# Innings               6
# Overs                20
# Ballnumber           10
# Batter              605
# Bowler              472
# Non-striker         595
# Batsman_run           7
# Extra_run             7
# Total_run             8
# Non_boundary          2
# IsWicketDelivery      2
# BattingTeam          17
# dtype: int64

# %%
dfb.describe()
# Out:
#                  ID        Innings          Overs     Ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          Batsman_run      Extra_run     Total_run   Non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# 25%         0.000000       0.000000       0.00000       0.000000
# 50%         1.000000       0.000000       1.00000       0.000000
# 75%         1.000000       0.000000       1.00000       0.000000
# max         6.000000       7.000000       7.00000       1.000000
#
#        IsWicketDelivery
# count     225954.000000
# mean           0.049351
# std            0.216600
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
dfb.describe()[['Overs','Ballnumber','Batsman_run','Extra_run','Total_run']]
# Out:
#                Overs     Ballnumber    Batsman_run      Extra_run  \
# count  225954.000000  225954.000000  225954.000000  225954.000000
# mean        9.185679       3.619750       1.243523       0.066907
# std         5.681797       1.810633       1.618166       0.341470
# min         0.000000       1.000000       0.000000       0.000000
# 25%         4.000000       2.000000       0.000000       0.000000
# 50%         9.000000       4.000000       1.000000       0.000000
# 75%        14.000000       5.000000       1.000000       0.000000
# max        19.000000      10.000000       6.000000       7.000000
#
#           Total_run
# count  225954.00000
# mean        1.31043
# std         1.60605
# min         0.00000
# 25%         0.00000
# 50%         1.00000
# 75%         1.00000
# max         7.00000

# %% [markdown]
# # Exploratory Data Analysis
# Now we will analyze our IPL dataset containing information about macthes, venue and scoring of IPL 15 seasons 2008 to 2022.

# %% [markdown]
# ####  whar are the *total* team played from 2008-2022 ?

# %%
print(df.shape)
dfb.shape
# Out:
# (950, 19)
# (225954, 13)

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
teamsdf =pd.DataFrame(df['Team1'].value_counts().index )

# %%
teamsdf.columns
# Out:
# Index(['Team1'], dtype='object')

# %%
teamsdf.rename(columns={'Team1':'Teams'}, inplace =True)

# %%
teamsdf
# Out:
#                           Teams
# 0   Royal Challengers Bangalore
# 1                Delhi Capitals
# 2                Mumbai Indians
# 3           Chennai Super Kings
# 4                  Punjab Kings
# 5         Kolkata Knight Riders
# 6              Rajasthan Royals
# 7           Sunrisers Hyderabad
# 8               Deccan Chargers
# 9                 Pune Warriors
# 10                Gujarat Lions
# 11       Rising Pune Supergiant
# 12         Lucknow Super Giants
# 13               Gujarat Titans
# 14         Kochi Tuskers Kerala

# %%
len(teamsdf)
# Out:
# 15

# %% [markdown]
# ## there are 15 teams  and in teamdf you can see the list of teams

# %% [markdown]
# ### total matches played by each team

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Gujarat Lions                   16
# Rising Pune Supergiant          14
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df[['Team1','Team2']]
# Out:
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947               Delhi Capitals             Rajasthan Royals
# 948                 Punjab Kings          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
# [950 rows x 2 columns]

# %%
pd.concat([df['Team1'],df['Team2']])
# Out:
# 0                 Rajasthan Royals
# 1      Royal Challengers Bangalore
# 2      Royal Challengers Bangalore
# 3                 Rajasthan Royals
# 4              Sunrisers Hyderabad
#                   ...
# 945                Deccan Chargers
# 946    Royal Challengers Bangalore
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Length: 1900, dtype: object

# %%
pd.concat([df['Team1'],df['Team2']]).value_counts()
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Delhi Capitals                 224
# Kolkata Knight Riders          223
# Punjab Kings                   218
# Chennai Super Kings            208
# Rajasthan Royals               192
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Pune Warriors                   46
# Rising Pune Supergiant          30
# Gujarat Lions                   30
# Gujarat Titans                  16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Name: count, dtype: int64

# %%
teams_matches = pd.concat([df['Team1'],df['Team2']]).value_counts()
pd.DataFrame(teams_matches)
# Out:
#                              count
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Delhi Capitals                 224
# Kolkata Knight Riders          223
# Punjab Kings                   218
# Chennai Super Kings            208
# Rajasthan Royals               192
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Pune Warriors                   46
# Rising Pune Supergiant          30
# Gujarat Lions                   30
# Gujarat Titans                  16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14

# %%
teams_matches = pd.concat([df['Team1'],df['Team2']]).value_counts()
teams_matches = pd.DataFrame(teams_matches).reset_index()
teams_matches.rename(columns={'index':'Teams',0:'Total_Matches'},inplace=True)

# %%
teams_matches
# Out:
#                           Teams  count
# 0                Mumbai Indians    231
# 1   Royal Challengers Bangalore    226
# 2                Delhi Capitals    224
# 3         Kolkata Knight Riders    223
# 4                  Punjab Kings    218
# 5           Chennai Super Kings    208
# 6              Rajasthan Royals    192
# 7           Sunrisers Hyderabad    152
# 8               Deccan Chargers     75
# 9                 Pune Warriors     46
# 10       Rising Pune Supergiant     30
# 11                Gujarat Lions     30
# 12               Gujarat Titans     16
# 13         Lucknow Super Giants     15
# 14         Kochi Tuskers Kerala     14

# %% [markdown]
# ### visualization
#
# matplotlib

# %%
def get_color(name, number):
    pal = list(sns.color_palette(palette=name, n_colors=number).as_hex())
    return pal

# %%
pal_vi = get_color('viridis_r', len(df))
pal_vi
# Out:
# ['#fde725',
#  '#fde725',
#  '#fde725',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f6e620',
#  '#f6e620',
#  '#f6e620',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#ece51b',
#  '#ece51b',
#  '#ece51b',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e5e419',
#  '#e5e419',
#  '#e5e419',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dae319',
#  '#dae319',
#  '#dae319',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d2e21b',
#  '#d2e21b',
#  '#d2e21b',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#cde11d',
#  '#cde11d',
#  '#cde11d',
#  '#cde11d',
#  '#cae11f',
#  '#cae11f',
#  '#cae11f',
#  '#cae11f',
#  '#c8e020',
#  '#c8e020',
#  '#c8e020',
#  '#c5e021',
#  '#c5e021',
#  '#c5e021',
#  '#c5e021',
#  '#c2df23',
#  '#c2df23',
#  '#c2df23',
#  '#c2df23',
#  '#c0df25',
#  '#c0df25',
#  '#c0df25',
#  '#bddf26',
#  '#bddf26',
#  '#bddf26',
#  '#bddf26',
#  '#bade28',
#  '#bade28',
#  '#bade28',
#  '#bade28',
#  '#b8de29',
#  '#b8de29',
#  '#b8de29',
#  '#b8de29',
#  '#b5de2b',
#  '#b5de2b',
#  '#b5de2b',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b2dd2d',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#b0dd2f',
#  '#addc30',
#  '#addc30',
#  '#addc30',
#  '#aadc32',
#  '#aadc32',
#  '#aadc32',
#  '#aadc32',
#  '#a8db34',
#  '#a8db34',
#  '#a8db34',
#  '#a8db34',
#  '#a5db36',
#  '#a5db36',
#  '#a5db36',
#  '#a5db36',
#  '#a2da37',
#  '#a2da37',
#  '#a2da37',
#  '#a0da39',
#  '#a0da39',
#  '#a0da39',
#  '#a0da39',
#  '#9dd93b',
#  '#9dd93b',
#  '#9dd93b',
#  '#9dd93b',
#  '#9bd93c',
#  '#9bd93c',
#  '#9bd93c',
#  '#98d83e',
#  '#98d83e',
#  '#98d83e',
#  '#98d83e',
#  '#95d840',
#  '#95d840',
#  '#95d840',
#  '#95d840',
#  '#93d741',
#  '#93d741',
#  '#93d741',
#  '#93d741',
#  '#90d743',
#  '#90d743',
#  '#90d743',
#  '#8ed645',
#  '#8ed645',
#  '#8ed645',
#  '#8ed645',
#  '#8bd646',
#  '#8bd646',
#  '#8bd646',
#  '#8bd646',
#  '#89d548',
#  '#89d548',
#  '#89d548',
#  '#86d549',
#  '#86d549',
#  '#86d549',
#  '#86d549',
#  '#84d44b',
#  '#84d44b',
#  '#84d44b',
#  '#84d44b',
#  '#81d34d',
#  '#81d34d',
#  '#81d34d',
#  '#81d34d',
#  '#7fd34e',
#  '#7fd34e',
#  '#7fd34e',
#  '#7cd250',
#  '#7cd250',
#  '#7cd250',
#  '#7cd250',
#  '#7ad151',
#  '#7ad151',
#  '#7ad151',
#  '#7ad151',
#  '#77d153',
#  '#77d153',
#  '#77d153',
#  '#75d054',
#  '#75d054',
#  '#75d054',
#  '#75d054',
#  '#73d056',
#  '#73d056',
#  '#73d056',
#  '#73d056',
#  '#70cf57',
#  '#70cf57',
#  '#70cf57',
#  '#70cf57',
#  '#6ece58',
#  '#6ece58',
#  '#6ece58',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#6ccd5a',
#  '#69cd5b',
#  '#69cd5b',
#  '#69cd5b',
#  '#69cd5b',
#  '#67cc5c',
#  '#67cc5c',
#  '#67cc5c',
#  '#65cb5e',
#  '#65cb5e',
#  '#65cb5e',
#  '#65cb5e',
#  '#63cb5f',
#  '#63cb5f',
#  '#63cb5f',
#  '#63cb5f',
#  '#60ca60',
#  '#60ca60',
#  '#60ca60',
#  '#60ca60',
#  '#5ec962',
#  '#5ec962',
#  '#5ec962',
#  '#5cc863',
#  '#5cc863',
#  '#5cc863',
#  '#5cc863',
#  '#5ac864',
#  '#5ac864',
#  '#5ac864',
#  '#5ac864',
#  '#58c765',
#  '#58c765',
#  '#58c765',
#  '#56c667',
#  '#56c667',
#  '#56c667',
#  '#56c667',
#  '#54c568',
#  '#54c568',
#  '#54c568',
#  '#54c568',
#  '#52c569',
#  '#52c569',
#  '#52c569',
#  '#52c569',
#  '#50c46a',
#  '#50c46a',
#  '#50c46a',
#  '#4ec36b',
#  '#4ec36b',
#  '#4ec36b',
#  '#4ec36b',
#  '#4cc26c',
#  '#4cc26c',
#  '#4cc26c',
#  '#4cc26c',
#  '#4ac16d',
#  '#4ac16d',
#  '#4ac16d',
#  '#48c16e',
#  '#48c16e',
#  '#48c16e',
#  '#48c16e',
#  '#46c06f',
#  '#46c06f',
#  '#46c06f',
#  '#46c06f',
#  '#44bf70',
#  '#44bf70',
#  '#44bf70',
#  '#44bf70',
#  '#42be71',
#  '#42be71',
#  '#42be71',
#  '#40bd72',
#  '#40bd72',
#  '#40bd72',
#  '#40bd72',
#  '#3fbc73',
#  '#3fbc73',
#  '#3fbc73',
#  '#3fbc73',
#  '#3dbc74',
#  '#3dbc74',
#  '#3dbc74',
#  '#3bbb75',
#  '#3bbb75',
#  '#3bbb75',
#  '#3bbb75',
#  '#3aba76',
#  '#3aba76',
#  '#3aba76',
#  '#3aba76',
#  '#38b977',
#  '#38b977',
#  '#38b977',
#  '#38b977',
#  '#37b878',
#  '#37b878',
#  '#37b878',
#  '#35b779',
#  '#35b779',
#  '#35b779',
#  '#35b779',
#  '#34b679',
#  '#34b679',
#  '#34b679',
#  '#34b679',
#  '#32b67a',
#  '#32b67a',
#  '#32b67a',
#  '#31b57b',
#  '#31b57b',
#  '#31b57b',
#  '#31b57b',
#  '#2fb47c',
#  '#2fb47c',
#  '#2fb47c',
#  '#2fb47c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2eb37c',
#  '#2db27d',
#  '#2db27d',
#  '#2db27d',
#  '#2cb17e',
#  '#2cb17e',
#  '#2cb17e',
#  '#2cb17e',
#  '#2ab07f',
#  '#2ab07f',
#  '#2ab07f',
#  '#2ab07f',
#  '#29af7f',
#  '#29af7f',
#  '#29af7f',
#  '#28ae80',
#  '#28ae80',
#  '#28ae80',
#  '#28ae80',
#  '#27ad81',
#  '#27ad81',
#  '#27ad81',
#  '#27ad81',
#  '#26ad81',
#  '#26ad81',
#  '#26ad81',
#  '#26ad81',
#  '#25ac82',
#  '#25ac82',
#  '#25ac82',
#  '#25ab82',
#  '#25ab82',
#  '#25ab82',
#  '#25ab82',
#  '#24aa83',
#  '#24aa83',
#  '#24aa83',
#  '#24aa83',
#  '#23a983',
#  '#23a983',
#  '#23a983',
#  '#22a884',
#  '#22a884',
#  '#22a884',
#  '#22a884',
#  '#22a785',
#  '#22a785',
#  '#22a785',
#  '#22a785',
#  '#21a685',
#  '#21a685',
#  '#21a685',
#  '#21a685',
#  '#21a585',
#  '#21a585',
#  '#21a585',
#  '#20a486',
#  '#20a486',
#  '#20a486',
#  '#20a486',
#  '#20a386',
#  '#20a386',
#  '#20a386',
#  '#20a386',
#  '#1fa287',
#  '#1fa287',
#  '#1fa287',
#  '#1fa187',
#  '#1fa187',
#  '#1fa187',
#  '#1fa187',
#  '#1fa188',
#  '#1fa188',
#  '#1fa188',
#  '#1fa188',
#  '#1fa088',
#  '#1fa088',
#  '#1fa088',
#  '#1fa088',
#  '#1f9f88',
#  '#1f9f88',
#  '#1f9f88',
#  '#1f9e89',
#  '#1f9e89',
#  '#1f9e89',
#  '#1f9e89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9d89',
#  '#1e9c89',
#  '#1e9c89',
#  '#1e9c89',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1e9b8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f9a8a',
#  '#1f998a',
#  '#1f998a',
#  '#1f998a',
#  '#1f998a',
#  '#1f988b',
#  '#1f988b',
#  '#1f988b',
#  '#1f978b',
#  '#1f978b',
#  '#1f978b',
#  '#1f978b',
#  '#1f968b',
#  '#1f968b',
#  '#1f968b',
#  '#1f968b',
#  '#1f958b',
#  '#1f958b',
#  '#1f958b',
#  '#1f948c',
#  '#1f948c',
#  '#1f948c',
#  '#1f948c',
#  '#20938c',
#  '#20938c',
#  '#20938c',
#  '#20938c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#20928c',
#  '#21918c',
#  '#21918c',
#  '#21918c',
#  '#21918c',
#  '#21908d',
#  '#21908d',
#  '#21908d',
#  '#21908d',
#  '#218f8d',
#  '#218f8d',
#  '#218f8d',
#  '#218e8d',
#  '#218e8d',
#  '#218e8d',
#  '#218e8d',
#  '#228d8d',
#  '#228d8d',
#  '#228d8d',
#  '#228d8d',
#  '#228c8d',
#  '#228c8d',
#  '#228c8d',
#  '#228c8d',
#  '#228b8d',
#  '#228b8d',
#  '#228b8d',
#  '#238a8d',
#  '#238a8d',
#  '#238a8d',
#  '#238a8d',
#  '#23898e',
#  '#23898e',
#  '#23898e',
#  '#23898e',
#  '#23888e',
#  '#23888e',
#  '#23888e',
#  '#24878e',
#  '#24878e',
#  '#24878e',
#  '#24878e',
#  '#24868e',
#  '#24868e',
#  '#24868e',
#  '#24868e',
#  '#25858e',
#  '#25858e',
#  '#25858e',
#  '#25858e',
#  '#25848e',
#  '#25848e',
#  '#25848e',
#  '#25838e',
#  '#25838e',
#  '#25838e',
#  '#25838e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26828e',
#  '#26818e',
#  '#26818e',
#  '#26818e',
#  '#26818e',
#  '#27808e',
#  '#27808e',
#  '#27808e',
#  '#27808e',
#  '#277f8e',
#  '#277f8e',
#  '#277f8e',
#  '#277f8e',
#  '#277e8e',
#  '#277e8e',
#  '#277e8e',
#  '#287d8e',
#  '#287d8e',
#  '#287d8e',
#  '#287d8e',
#  '#287c8e',
#  '#287c8e',
#  '#287c8e',
#  '#287c8e',
#  '#297b8e',
#  '#297b8e',
#  '#297b8e',
#  '#297a8e',
#  '#297a8e',
#  '#297a8e',
#  '#297a8e',
#  '#29798e',
#  '#29798e',
#  '#29798e',
#  '#29798e',
#  '#2a788e',
#  '#2a788e',
#  '#2a788e',
#  '#2a788e',
#  '#2a778e',
#  '#2a778e',
#  '#2a778e',
#  '#2a768e',
#  '#2a768e',
#  '#2a768e',
#  '#2a768e',
#  '#2b758e',
#  '#2b758e',
#  '#2b758e',
#  '#2b758e',
#  '#2b748e',
#  '#2b748e',
#  '#2b748e',
#  '#2c738e',
#  '#2c738e',
#  '#2c738e',
#  '#2c738e',
#  '#2c728e',
#  '#2c728e',
#  '#2c728e',
#  '#2c728e',
#  '#2c718e',
#  '#2c718e',
#  '#2c718e',
#  '#2c718e',
#  '#2d718e',
#  '#2d718e',
#  '#2d718e',
#  '#2d708e',
#  '#2d708e',
#  '#2d708e',
#  '#2d708e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6f8e',
#  '#2e6e8e',
#  '#2e6e8e',
#  '#2e6e8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2e6d8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6c8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#2f6b8e',
#  '#306a8e',
#  '#306a8e',
#  '#306a8e',
#  '#30698e',
#  '#30698e',
#  '#30698e',
#  '#30698e',
#  '#31688e',
#  '#31688e',
#  '#31688e',
#  '#31688e',
#  '#31678e',
#  '#31678e',
#  '#31678e',
#  '#31668e',
#  '#31668e',
#  '#31668e',
#  '#31668e',
#  '#32658e',
#  '#32658e',
#  '#32658e',
#  '#32658e',
#  '#32648e',
#  '#32648e',
#  '#32648e',
#  '#32648e',
#  '#33638d',
#  '#33638d',
#  '#33638d',
#  '#33628d',
#  '#33628d',
#  '#33628d',
#  '#33628d',
#  '#34618d',
#  '#34618d',
#  '#34618d',
#  '#34618d',
#  '#34608d',
#  '#34608d',
#  '#34608d',
#  '#355f8d',
#  '#355f8d',
#  '#355f8d',
#  '#355f8d',
#  '#355e8d',
#  '#355e8d',
#  '#355e8d',
#  '#355e8d',
#  '#365d8d',
#  '#365d8d',
#  '#365d8d',
#  '#365d8d',
#  '#365c8d',
#  '#365c8d',
#  '#365c8d',
#  '#375b8d',
#  '#375b8d',
#  '#375b8d',
#  '#375b8d',
#  '#375a8c',
#  '#375a8c',
#  '#375a8c',
#  '#375a8c',
#  '#38598c',
#  '#38598c',
#  '#38598c',
#  '#38588c',
#  '#38588c',
#  '#38588c',
#  '#38588c',
#  '#39568c',
#  '#39568c',
#  '#39568c',
#  '#39568c',
#  '#39558c',
#  '#39558c',
#  '#39558c',
#  '#39558c',
#  '#3a548c',
#  '#3a548c',
#  '#3a548c',
#  '#3a538b',
#  '#3a538b',
#  '#3a538b',
#  '#3a538b',
#  '#3b528b',
#  '#3b528b',
#  '#3b528b',
#  '#3b528b',
#  '#3b518b',
#  '#3b518b',
#  '#3b518b',
#  '#3c508b',
#  '#3c508b',
#  '#3c508b',
#  '#3c508b',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3c4f8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4e8a',
#  '#3d4d8a',
#  '#3d4d8a',
#  '#3d4d8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4c8a',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4a89',
#  '#3e4989',
#  '#3e4989',
#  '#3e4989',
#  '#3f4889',
#  '#3f4889',
#  '#3f4889',
#  '#3f4889',
#  '#3f4788',
#  '#3f4788',
#  '#3f4788',
#  '#3f4788',
#  '#404688',
#  '#404688',
#  '#404688',
#  '#404688',
#  '#404588',
#  '#404588',
#  '#404588',
#  '#414487',
#  '#414487',
#  '#414487',
#  '#414487',
#  '#414287',
#  '#414287',
#  '#414287',
#  '#414287',
#  '#424186',
#  '#424186',
#  '#424186',
#  '#424086',
#  '#424086',
#  '#424086',
#  '#424086',
#  '#423f85',
#  '#423f85',
#  '#423f85',
#  '#423f85',
#  '#433e85',
#  '#433e85',
#  '#433e85',
#  '#433e85',
#  '#433d84',
#  '#433d84',
#  '#433d84',
#  '#443b84',
#  '#443b84',
#  '#443b84',
#  '#443b84',
#  '#443a83',
#  '#443a83',
#  '#443a83',
#  '#443a83',
#  '#443983',
#  '#443983',
#  '#443983',
#  '#453882',
#  '#453882',
#  '#453882',
#  '#453882',
#  '#453781',
#  '#453781',
#  '#453781',
#  '#453781',
#  '#453581',
#  '#453581',
#  '#453581',
#  '#453581',
#  '#463480',
#  '#463480',
#  '#463480',
#  '#46337f',
#  '#46337f',
#  '#46337f',
#  '#46337f',
#  '#46327e',
#  '#46327e',
#  '#46327e',
#  '#46327e',
#  '#46307e',
#  '#46307e',
#  '#46307e',
#  '#472f7d',
#  '#472f7d',
#  '#472f7d',
#  '#472f7d',
#  '#472e7c',
#  '#472e7c',
#  '#472e7c',
#  '#472e7c',
#  '#472d7b',
#  '#472d7b',
#  '#472d7b',
#  '#472d7b',
#  '#472c7a',
#  '#472c7a',
#  '#472c7a',
#  '#472a7a',
#  '#472a7a',
#  '#472a7a',
#  '#472a7a',
#  '#482979',
#  '#482979',
#  '#482979',
#  '#482979',
#  '#482878',
#  '#482878',
#  '#482878',
#  '#482677',
#  '#482677',
#  '#482677',
#  '#482677',
#  '#482576',
#  '#482576',
#  '#482576',
#  '#482576',
#  '#482475',
#  '#482475',
#  '#482475',
#  '#482475',
#  '#482374',
#  '#482374',
#  '#482374',
#  '#482173',
#  '#482173',
#  '#482173',
#  '#482173',
#  '#482071',
#  '#482071',
#  '#482071',
#  '#482071',
#  '#481f70',
#  '#481f70',
#  '#481f70',
#  '#481d6f',
#  '#481d6f',
#  '#481d6f',
#  '#481d6f',
#  '#481c6e',
#  '#481c6e',
#  '#481c6e',
#  '#481c6e',
#  '#481b6d',
#  '#481b6d',
#  '#481b6d',
#  '#481b6d',
#  '#481a6c',
#  '#481a6c',
#  '#481a6c',
#  '#48186a',
#  '#48186a',
#  '#48186a',
#  '#48186a',
#  '#481769',
#  '#481769',
#  '#481769',
#  '#481769',
#  '#481668',
#  '#481668',
#  '#481668',
#  '#481467',
#  '#481467',
#  '#481467',
#  '#481467',
#  '#471365',
#  '#471365',
#  '#471365',
#  '#471365',
#  '#471164',
#  '#471164',
#  '#471164',
#  '#471164',
#  '#471063',
#  '#471063',
#  '#471063',
#  '#470e61',
#  '#470e61',
#  '#470e61',
#  '#470e61',
#  '#470d60',
#  '#470d60',
#  '#470d60',
#  '#470d60',
#  '#460b5e',
#  '#460b5e',
#  '#460b5e',
#  '#460a5d',
#  '#460a5d',
#  '#460a5d',
#  '#460a5d',
#  '#46085c',
#  '#46085c',
#  '#46085c',
#  '#46085c',
#  '#46075a',
#  '#46075a',
#  '#46075a',
#  '#46075a',
#  '#450559',
#  '#450559',
#  '#450559',
#  '#450457',
#  '#450457',
#  '#450457',
#  '#450457',
#  '#440256',
#  '#440256',
#  '#440256',
#  '#440256',
#  '#440154',
#  '#440154',
#  '#440154']

# %%
# Set figure size
plt.figure(figsize=(30, 10))

# %%
teams_matches.rename(columns={'count':'Total_Matches'},inplace=True)

# %%
# Create bar plot
teams_matches1 = teams_matches.head(10)
bars = plt.bar(
    teams_matches1['Teams'],
    teams_matches1['Total_Matches'],
    #color=pal_vi[:len(teams_matches1)]  # Use your color palette
)


plt.xlabel('Teams')
plt.ylabel('Total Matches')
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height}',
        ha='center',
        va='bottom',
        fontsize=10
    )

# Customize plot appearance
plt.xlabel('Teams')
plt.ylabel('Total Matches')
plt.xticks(rotation=45)
plt.gca().set_facecolor('white')   # Plot background
plt.gcf().set_facecolor('white')   # Figure background

# Remove top and right spines for a cleaner look
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
team_mapping = {
    'Mumbai Indians': 'MI',
    'Royal Challengers Bangalore': 'RCB',
    'Delhi Capitals': 'DC',
    'Kolkata Knight Riders': 'KKR',
    'Punjab Kings': 'PBKS',
    'Chennai Super Kings': 'CSK',
    'Rajasthan Royals': 'RR',
    'Sunrisers Hyderabad': 'SRH',
    'Deccan Chargers': 'DCG',
    'Pune Warriors': 'PW',
    'Rising Pune Supergiant': 'RPS',
    'Gujarat Lions': 'GL',
    'Gujarat Titans': 'GT',
    'Lucknow Super Giants': 'LSG',
    'Kochi Tuskers Kerala': 'KTK'
}

teams_matches.replace(team_mapping, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize': (20, 10)})

ax = sns.barplot(
    data=teams_matches,
    x='Teams',
    y='Total_Matches',
    hue='Teams',          # Assign a different color to each team
    palette='Set3',       # You can change this to Set2, tab10, viridis, etc.
    legend=False
)

for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
pip install plotly --upgrade --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
teams_matches
# Out:
#    Teams  Total_Matches
# 0     MI            231
# 1    RCB            226
# 2     DC            224
# 3    KKR            223
# 4   PBKS            218
# 5    CSK            208
# 6     RR            192
# 7    SRH            152
# 8    DCG             75
# 9     PW             46
# 10   RPS             30
# 11    GL             30
# 12    GT             16
# 13   LSG             15
# 14   KTK             14

# %%
import plotly.express as px
fig = px.bar(teams_matches, x='Teams', y='Total_Matches', text='Total_Matches',
             color ='Teams', color_discrete_sequence=pal_vi)

fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')
fig.update_layout({'plot_bgcolor': 'white',
                   'paper_bgcolor': 'white'})

fig.update_layout(width=1100, height=500,
                  margin = dict(t=15, l=15, r=15, b=15))
fig.show()

# %% [markdown]
# By above analysis we can see that number of matches played by Mumbai indians, Royal Challengers Bangalore, Delhi Capitals, Kolkata Knight Riders, Punjab Kings, Chennai Super Kings is high. On the other hand, Punjab Kings, Kochi Tuskers Kerala, Pune Warriors, Gujarat Lions, Rising Pune Supergiant are the defunct team by BCCI.

# %% [markdown]
# ## Winning Ratio Analysis

# %%
win_df=teams_matches
win_df['total_Wins']=df['WinningTeam'].value_counts().reset_index()['WinningTeam']

# %%
win_df = teams_matches

# %%
df['WinningTeam'].value_counts().reset_index()['count']
# Out:
# 0     131
# 1     121
# 2     114
# 3     109
# 4     103
# 5     101
# 6      96
# 7      75
# 8      29
# 9      15
# 10     13
# 11     12
# 12     12
# 13      9
# 14      6
# 15      4
# Name: count, dtype: int64

# %%
win_df = teams_matches
win_df['total_wins']=df['WinningTeam'].value_counts().reset_index()['count']

# %%
win_df
# Out:
#    Teams  Total_Matches                   total_Wins  total_wins
# 0     MI            231               Mumbai Indians         131
# 1    RCB            226          Chennai Super Kings         121
# 2     DC            224        Kolkata Knight Riders         114
# 3    KKR            223  Royal Challengers Bangalore         109
# 4   PBKS            218               Delhi Capitals         103
# 5    CSK            208                 Punjab Kings         101
# 6     RR            192             Rajasthan Royals          96
# 7    SRH            152          Sunrisers Hyderabad          75
# 8    DCG             75              Deccan Chargers          29
# 9     PW             46       Rising Pune Supergiant          15
# 10   RPS             30                Gujarat Lions          13
# 11    GL             30               Gujarat Titans          12
# 12    GT             16                Pune Warriors          12
# 13   LSG             15         Lucknow Super Giants           9
# 14   KTK             14         Kochi Tuskers Kerala           6

# %%
win_df = teams_matches
win_df['total_wins']=df['WinningTeam'].value_counts().reset_index()['count']
win_df['win_ratio']= round((win_df['total_wins']/win_df['Total_Matches']),2)*100
win_df
# Out:
#    Teams  Total_Matches                   total_Wins  total_wins  win_ratio
# 0     MI            231               Mumbai Indians         131       57.0
# 1    RCB            226          Chennai Super Kings         121       54.0
# 2     DC            224        Kolkata Knight Riders         114       51.0
# 3    KKR            223  Royal Challengers Bangalore         109       49.0
# 4   PBKS            218               Delhi Capitals         103       47.0
# 5    CSK            208                 Punjab Kings         101       49.0
# 6     RR            192             Rajasthan Royals          96       50.0
# 7    SRH            152          Sunrisers Hyderabad          75       49.0
# 8    DCG             75              Deccan Chargers          29       39.0
# 9     PW             46       Rising Pune Supergiant          15       33.0
# 10   RPS             30                Gujarat Lions          13       43.0
# 11    GL             30               Gujarat Titans          12       40.0
# 12    GT             16                Pune Warriors          12       75.0
# 13   LSG             15         Lucknow Super Giants           9       60.0
# 14   KTK             14         Kochi Tuskers Kerala           6       43.0

# %%
plt.figure(figsize=(15,6.5))
sns.set_style('darkgrid')
wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False, palette='viridis_r')
wi.set_xticklabels(win_df['win_ratio'], rotation=55, fontdict={'fontsize':10})
plt.show()
# Out:
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\3300513310.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False, palette='viridis_r')
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\3300513310.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False, palette='viridis_r')
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\3300513310.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   wi.set_xticklabels(win_df['win_ratio'], rotation=55, fontdict={'fontsize':10})

# %% [markdown]
# ## Top 10 Batters that gets Player of Match Title

# %%
df['Player_of_Match'].value_counts().reset_index()
# Out:
#     Player_of_Match  count
# 0    AB de Villiers     25
# 1          CH Gayle     22
# 2         RG Sharma     18
# 3         DA Warner     18
# 4          MS Dhoni     17
# ..              ...    ...
# 258     SA Asnodkar      1
# 259      GD McGrath      1
# 260       SM Katich      1
# 261        JDP Oram      1
# 262     MF Maharoof      1
#
# [263 rows x 2 columns]

# %%
player_of_macth_df = df['Player_of_Match'].value_counts().reset_index()
player_of_macth_df.rename(columns={'index':'player_of_macth_df ','player_of_macth_df ':'count'},inplace=True)
top_10_Player_of_match = player_of_macth_df.head(10)

# %%
player_of_macth_df
# Out:
#     Player_of_Match  count
# 0    AB de Villiers     25
# 1          CH Gayle     22
# 2         RG Sharma     18
# 3         DA Warner     18
# 4          MS Dhoni     17
# ..              ...    ...
# 258     SA Asnodkar      1
# 259      GD McGrath      1
# 260       SM Katich      1
# 261        JDP Oram      1
# 262     MF Maharoof      1
#
# [263 rows x 2 columns]

# %%
plt.figure(figsize=(9,4))
plt.plot(top_10_Player_of_match['count'], top_10_Player_of_match['Player_of_Match'], 'o-g')

plt.xlabel('count')
plt.ylabel('Player of Match')

plt.title('Top 10 Player of Match')
plt.show()

# %% [markdown]
# Above analysis show that, with 25 man of the match trophies, **AB de Villiers** has most man of the match in IPL. While **CH Gayle** is in second number who has most man of the match in IPL.

# %% [markdown]
# ## Top 10 IPL hosted cities
# We will analyze the top cities that hosted IPL most time.

# %%
citraw = df['City'].value_counts().reset_index()
citraw.rename(columns={'index':'city','city':'count'},inplace=True)
top10_city_host = citraw.head(10)
top10_city_host
# Out:
#          City  count
# 0      Mumbai    159
# 1   Bangalore     80
# 2     Kolkata     79
# 3       Delhi     78
# 4     Chennai     67
# 5   Hyderabad     64
# 6     Sharjah     56
# 7  Chandigarh     56
# 8        Pune     51
# 9      Jaipur     47

# %%
plt.figure(figsize=(16,8))
palette_color = sns.color_palette("ch:s=.25,rot=-.25")
sns.barplot(x='count', y='City',palette = palette_color, data=top10_city_host);
plt.title('Top 10 IPL hosted cities');
plt.show()
# Out:
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\3035689334.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='count', y='City',palette = palette_color, data=top10_city_host);
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\3035689334.py:3: UserWarning:
# The palette list has fewer values (6) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='count', y='City',palette = palette_color, data=top10_city_host);

# %% [markdown]
# Mumbai hosted maximum matches of Indian Premium League.

# %% [markdown]
# ## Number of Matches hosted in Seasons

# %%
df["Season"]=pd.DatetimeIndex(df["Date"]).year
matches_in_season=df.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
matches_in_season
# Out:
#     Season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74

# %%
plt.figure(figsize=(12,5))

sns.barplot(x='Season', y='matches', data=matches_in_season);
plt.title('No of total matches per season');
plt.show()

# %% [markdown]
# There is chart that show total number of matches held in each Season of IPL. In 2011,2012,2013 and 2022 IPL number of total matches greater than other seasons.

# %% [markdown]
# ## Most Time Toss Winning Teams

# %%
df['TossWinner'].value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
most_toss_winner = df['TossWinner'].value_counts().reset_index()
most_toss_winner.rename(columns={'index':'TossWinner','TossWinner':'count'},inplace = True)
most_toss_winner
# Out:
#                           count  count
# 0                Mumbai Indians    123
# 1         Kolkata Knight Riders    114
# 2           Chennai Super Kings    109
# 3   Royal Challengers Bangalore    105
# 4              Rajasthan Royals     99
# 5                  Punjab Kings     94
# 6              Delhi Daredevils     80
# 7           Sunrisers Hyderabad     74
# 8               Deccan Chargers     43
# 9                Delhi Capitals     36
# 10                Pune Warriors     20
# 11                Gujarat Lions     15
# 12               Gujarat Titans     10
# 13         Kochi Tuskers Kerala      8
# 14         Lucknow Super Giants      7
# 15      Rising Pune Supergiants      7
# 16       Rising Pune Supergiant      6

# %%
plt.figure(figsize=(12,5))

sns.barplot(x='Season', y='matches', data=matches_in_season);
plt.title('No of total matches per season');
plt.show()

# %%
most_toss_winner = df['TossWinner'].value_counts().reset_index()
most_toss_winner.rename(columns={'TossWinner':'TossWinner','count':'count'} ,inplace = True)
most_toss_winner
# Out:
#                      TossWinner  count
# 0                Mumbai Indians    123
# 1         Kolkata Knight Riders    114
# 2           Chennai Super Kings    109
# 3   Royal Challengers Bangalore    105
# 4              Rajasthan Royals     99
# 5                  Punjab Kings     94
# 6              Delhi Daredevils     80
# 7           Sunrisers Hyderabad     74
# 8               Deccan Chargers     43
# 9                Delhi Capitals     36
# 10                Pune Warriors     20
# 11                Gujarat Lions     15
# 12               Gujarat Titans     10
# 13         Kochi Tuskers Kerala      8
# 14         Lucknow Super Giants      7
# 15      Rising Pune Supergiants      7
# 16       Rising Pune Supergiant      6

# %%
plt.figure(figsize=(16,12))
plt.plot(most_toss_winner['count'], most_toss_winner['TossWinner'], marker='s', c='r', ls='--', lw=2, ms=10, mew=2, mec='navy')

plt.xlabel('Toss Winner')
plt.ylabel('count')

plt.title('Most time toss winning teams');
plt.show()

# %% [markdown]
# Toss is the most important thing in the cricket, winning the toss has also impact on match win, we will analyze it later. First we can see that **Mumbai Indians**, **Kolkata Knight Riders** and **Chennai Super Kings** won toss most time in IPL history.

# %% [markdown]
# ## Toss Decision in each Season of IPL

# %%
plt.figure(figsize=(16,6))
color_palette = sns.color_palette("Spectral")
sns.countplot(x='Season', hue='TossDecision', data=df,palette=color_palette,saturation=1)
plt.title('Toss Decision in each Season of IPL');
plt.show()
# Out:
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\2029223289.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.countplot(x='Season', hue='TossDecision', data=df,palette=color_palette,saturation=1)

# %% [markdown]
# AIn 2016, 2017, 2018, and 2019 most of the teams were field first after winning the toss. But the data show that, in 2020 teams went for bat first after winning toss because in 2020 IPL was held in Dubai, and Dubai stadium's ground and weather conditions suit for bat first. After 2020, in 2021 and 2022 teams again chose the field first after winning toss because IPL held again in INDIA.

# %% [markdown]
# # Asking and Answering Questions

# %% [markdown]
# ## Which Team won greater IPL Trophies?

# %%
#go to matchnumber column
#.loc or .iloc

f1=(df['MatchNumber']=='Final')
winning_team=df[f1]

# %%
winning_team=winning_team['WinningTeam'].value_counts().reset_index().rename(columns={'index':'Team','winning_team':'Total Title'})

# %%
winning_team
# Out:
#              WinningTeam  count
# 0         Mumbai Indians      5
# 1    Chennai Super Kings      4
# 2  Kolkata Knight Riders      2
# 3         Gujarat Titans      1
# 4    Sunrisers Hyderabad      1
# 5        Deccan Chargers      1
# 6       Rajasthan Royals      1

# %%
winning_team=winning_team['WinningTeam'].value_counts().reset_index().rename(columns={'count':'Total Title'})

# %%
winning_team
# Out:
#              WinningTeam  Total Title
# 0         Mumbai Indians            1
# 1    Chennai Super Kings            1
# 2  Kolkata Knight Riders            1
# 3         Gujarat Titans            1
# 4    Sunrisers Hyderabad            1
# 5        Deccan Chargers            1
# 6       Rajasthan Royals            1

# %%
import plotly.express as px

# %%
fig = px.pie(winning_team, values=winning_team['Total Title'], names=winning_team['WinningTeam'],
             color =winning_team['Total Title'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# In most of the cases, team win the match after winnig toss.

# %% [markdown]
# ## Which batsmen have most runs in IPL history?

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'Batsman_run', 'Extra_run', 'Total_run', 'Non_boundary',
#        'IsWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %% [markdown]
# ## Who is the best wicket taker bowler in IPL history?

# %%
dfb.Bowler
# Out:
# 0         Mohammed Shami
# 1         Mohammed Shami
# 2         Mohammed Shami
# 3         Mohammed Shami
# 4         Mohammed Shami
#                ...
# 225949          I Sharma
# 225950          I Sharma
# 225951          I Sharma
# 225952         LR Shukla
# 225953         LR Shukla
# Name: Bowler, Length: 225954, dtype: object

# %%
wicket_tacker_bowler=IPL_ball_by_ball_df.groupby('bowler').sum().reset_index()
wicket_tacker_bowler = wicket_tacker_bowler.sort_values(by='isWicketDelivery',ascending=False).head(10)
wicket_tacker_bowler

# %%
dfb['IsWicketDelivery'].value_counts() # 0 - No wicket ,  1 - wicket 
### Check the bowlers column 
wicket_takers = dfb.groupby('Bowler').sum().reset_index()
wt = wicket_takers[['Bowler','IsWicketDelivery']]
wt.rename(columns={'IsWicketDelivery':'Total_Wickets'},inplace=True)
wt = wt.sort_values(by='Total_Wickets',ascending=False).head(10).reset_index(drop=True)
wt
# Out:
# C:\Users\klemp\AppData\Local\Temp\ipykernel_22584\2158081670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wt.rename(columns={'IsWicketDelivery':'Total_Wickets'},inplace=True)
#             Bowler  Total_Wickets
# 0         DJ Bravo            207
# 1       SL Malinga            188
# 2         A Mishra            175
# 3         R Ashwin            174
# 4        YS Chahal            172
# 5        SP Narine            171
# 6        PP Chawla            165
# 7          B Kumar            165
# 8        JJ Bumrah            161
# 9  Harbhajan Singh            161

# %%
wt
# Out:
#             Bowler  Total_Wickets
# 0         DJ Bravo            207
# 1       SL Malinga            188
# 2         A Mishra            175
# 3         R Ashwin            174
# 4        YS Chahal            172
# 5        SP Narine            171
# 6        PP Chawla            165
# 7          B Kumar            165
# 8        JJ Bumrah            161
# 9  Harbhajan Singh            161

# %%
ax = sns.barplot(wt,x='Bowler',y='Total_Wickets')
sns.set(rc={'figure.figsize':(1000,700)})
for bar in ax.containers:
    ax.bar_label(bar)  

plt.show()

# %%
# Set figure size before plotting
sns.set(rc={'figure.figsize': (20, 8)})

ax = sns.barplot(data=wt, x='Bowler', y='Total_Wickets')

# Add labels on bars
for bar in ax.containers:
    ax.bar_label(bar)

# Rotate x-axis labels vertically
plt.xticks(rotation=90)
# Increase font size and make tick labels bold
plt.setp(ax.get_xticklabels(), fontsize=20, fontweight='bold')
plt.setp(ax.get_yticklabels(), fontsize=24, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(wt['Bowler'], wt['Total_Wickets'], marker='o', c='c', ls='-.', lw=2, ms=10, mew=2, mec='navy')

plt.xlabel('Bowler')
plt.ylabel('Wickets taken')

plt.title('Top 10 wickets tackers');
plt.show()

# %% [markdown]
# By  the above plot and data we can see that **DJ Bravo** is the most wicket taker bowler in IPL history.

# %% [markdown]
# ## What is Toss Decision Ratio in IPL?

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#'TossWinner', 'TossDecision'
df['TossWinner'].value_counts().sum
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Punjab Kings                    94
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
d1=df[ 'TossDecision'].value_counts()

# %%
d1
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
d1 = d1.reset_index().rename(columns={'index':'TossDecision','TossDecision':'count'})

# %%
d1
# Out:
#    TossDecision  count  count  count
# 0             0      0  field    599
# 1             1      1    bat    351

# %%
total=df[ 'TossDecision'].value_counts().sum()

# %%
total
# Out:
# np.int64(950)

# %%
d1 =  df['TossDecision'].value_counts()

# %%
d1
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
d1 = d1.reset_index()

# %%
d1
# Out:
#   TossDecision  count
# 0        field    599
# 1          bat    351

# %%
d1['Ratio'] = d1['count'].apply(lambda x : round(x/total,2)*100)

# %%
fig = px.pie(  d1, values=d1['Ratio'], names=d1['TossDecision'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# In IPL we can see that most of the teams chose to field first after winning toss.

# %% [markdown]
# ## Is win depend on winning toss?

# %%
toss_vs_matchwin = (df.TossWinner==df.WinningTeam).value_counts()
toss_vs_matchwin
# Out:
# False    499
# True     451
# Name: count, dtype: int64

# %%
total = (df.TossWinner==df.WinningTeam).value_counts().sum()

# %%
toss_vs_matchwin = (df.TossWinner==df.WinningTeam).value_counts()
toss_vs_matchwin
# Out:
# False    499
# True     451
# Name: count, dtype: int64

# %%
tm = toss_vs_matchwin.reset_index().rename(columns={'index':'isTossWinner',0:'count'})
tm['Percentage'] = round((tm['count']/total)*100,2)
tm
# Out:
#    isTossWinner  count  Percentage
# 0         False    499       52.53
# 1          True    451       47.47

# %%
fig = px.pie(tm, values=tm['Percentage'], names=['Toss Lost','Toss Won'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# > Overall toss be a factor to win the match but remember around 52% times the teams which lost the toss have won the match due to their better performance

# %% [markdown]
# ## Which batsmen have most runs in IPL history?

# %%
highest_run_batsmans=dfb.groupby('Batter').sum().reset_index()
highest_run_batsmans = highest_run_batsmans.sort_values(by='Batsman_run',ascending=False).head(10)
highest_run_batsmans
# Out:
#              Batter          ID  Innings  Overs  Ballnumber  \
# 569         V Kohli  4557729029     7692  42599       18441
# 462        S Dhawan  4624377952     7287  31374       17981
# 130       DA Warner  3950963740     6376  27099       15161
# 430       RG Sharma  3768938581     6697  40783       16371
# 493        SK Raina  3095619985     5935  36252       15209
# 27   AB de Villiers  2921390058     4989  36682       12684
# 108        CH Gayle  2811701391     5097  21811       12774
# 339        MS Dhoni  3052807492     5425  52346       14056
# 452      RV Uthappa  3105050932     6106  27483       13920
# 256      KD Karthik  2794829612     4885  37942       12283
#
#                                                 Bowler  \
# 569  TA BoultTA BoultTA BoultTA BoultTA BoultM Pras...
# 462  Washington SundarFazalhaq FarooqiFazalhaq Faro...
# 130  HR ShokeenHR ShokeenHR ShokeenHR ShokeenDR Sam...
# 430  KK AhmedKK AhmedKK AhmedKK AhmedKK AhmedKK Ahm...
# 493  YS ChahalYS ChahalYS ChahalYS ChahalPWH de Sil...
# 27   SP NarineSP NarineSP NarineCV VarunCV VarunCV ...
# 108  JO HolderJO HolderSandeep SharmaSandeep Sharma...
# 339  YS ChahalYS ChahalYS ChahalYS ChahalTA BoultTA...
# 452  DR SamsDR SamsDR SamsDR SamsJJ BumrahJJ Bumrah...
# 256  R AshwinR AshwinYS ChahalYS ChahalYS ChahalOC ...
#
#                                            Non-striker  Batsman_run  \
# 569  F du PlessisF du PlessisF du PlessisF du Pless...         6634
# 462  JM BairstowJM BairstowJM BairstowM Shahrukh Kh...         6244
# 130  PP ShawPP ShawPP ShawPP ShawPP ShawPP ShawSN K...         5883
# 430  Ishan KishanIshan KishanIshan KishanIshan Kish...         5881
# 493  AT RayuduAT RayuduAT RayuduAT RayuduMS DhoniMS...         5536
# 27   GJ MaxwellGJ MaxwellGJ MaxwellGJ MaxwellGJ Max...         5181
# 108  MA AgarwalMA AgarwalAK MarkramAK MarkramAK Mar...         4997
# 339  MM AliMM AliMM AliMM AliMM AliMM AliMM AliMM A...         4978
# 452  RD GaikwadRD GaikwadRD GaikwadRD GaikwadRD Gai...         4954
# 256  MK LomrorMK LomrorMK LomrorMK LomrorMK LomrorM...         4377
#
#      Extra_run  Total_run  Non_boundary  IsWicketDelivery  \
# 569        242       6876             2               193
# 462        317       6561             1               179
# 130        308       6191             0               143
# 430        202       6083             1               203
# 493        244       5780             0               168
# 27         173       5354             0               125
# 108        339       5336             1               128
# 339        243       5221             0               142
# 452        292       5246             0               184
# 256        195       4572             0               168
#
#                                            BattingTeam
# 569  Royal Challengers BangaloreRoyal Challengers B...
# 462  Punjab KingsPunjab KingsPunjab KingsPunjab Kin...
# 130  Delhi CapitalsDelhi CapitalsDelhi CapitalsDelh...
# 430  Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
# 493  Chennai Super KingsChennai Super KingsChennai ...
# 27   Royal Challengers BangaloreRoyal Challengers B...
# 108  Punjab KingsPunjab KingsPunjab KingsPunjab Kin...
# 339  Chennai Super KingsChennai Super KingsChennai ...
# 452  Chennai Super KingsChennai Super KingsChennai ...
# 256  Royal Challengers BangaloreRoyal Challengers B...

# %%
highest_run_batsmans=dfb.groupby('Batter').sum().reset_index()
highest_run_batsmans = highest_run_batsmans.sort_values(by='Batsman_run',ascending=False).head(10)
highest_run_batsmans[['Batter','Batsman_run']]
# Out:
#              Batter  Batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %%
plt.figure(figsize=(12,5))
palette_color = sns.color_palette('flare')
plt.pie(highest_run_batsmans['Batsman_run'],labels=highest_run_batsmans['Batter'],colors=palette_color,autopct='%.0f%%')
plt.title('BATSMEN WITH MOST RUNS IN IPL HISTORY')
plt.show()

# %% [markdown]
# By analyzing data we can see that **V Kholi** has maximum runs in the history of IPL followed by **S Dhawan**, **DA Warner** and **RG Sharma**.

# %% [markdown]
# ### Inferences and Conclusion (Story Telling)
# - We analyzing the IPL dataset by different techniques and by plotting charts. We get the information that Mumbai Indians play most matches than other teams and Mumbai Indians winning ratio is also good. So, we get that Mumbai Indian is most successful team of IPL. We also get that Virat Kholi is the most valuable player of IPL beacause he become most time player of match and he is also a batsmen of most runs in IPL history. And DJ Bravo is most wicket taker bowler in IPL history. We also analyze that most toss winning teams chose to field first and most of the toss winning teams winned up 47% of matches but remaining 53% owned one who lost but even if the team has good player they can make the team to win matches reagardless of toss factor . So, we can say that winnig toss depend on match win.
#
# - In this analysis, we also get that in which season most matches played and which city hosted most matches of IPL. We also fin that which team won most time the title of winning IPL and which is the most toss winning team in IPL.
#
# I wish you all will like my project. This Exploratory Data Analysis can be improve and can gives more information by plotting and visulizing different charts.
